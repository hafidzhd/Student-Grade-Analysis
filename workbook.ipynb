# %% [markdown]
# __Author : Hafidzati Hikmadani <br>
# Date   : November 30th 2021__

# %% [markdown]
# ## Background
#
# In school, student variety of final grade of each study. This final grade might happened because some factors from internal student or from external student. To get to know the factors which give strong impact, we need conduct a research against some sample of data of student final grade. This way is to increase the quality of school to treat their student so they could produce more valuable and good students.
#
# The purpose of this project is focusing to analyze the attributes which could affect Student Final Grade in Math and Portugese.

# %% [markdown]
# ## About Dataset

# %% [markdown]
# __Context :__
# The data were obtained in a survey of students math and portuguese language courses in secondary school. It contains a lot of interesting social, gender and study information about students. You can use it for some EDA or try to predict students final grade.
#
# __Content:__
# Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
#
# 1. school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# 2. sex - student's sex (binary: 'F' - female or 'M' - male)
# 3. age - student's age (numeric: from 15 to 22)
# 4. address - student's home address type (binary: 'U' - urban or 'R' - rural)
# 5. famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# 6. Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# 7. Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# 9. Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# 10. Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 11. Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 12. reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# 13. guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# 14. traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# 15. studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# 16. failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# 17. schoolsup - extra educational support (binary: yes or no)
# 18. famsup - family educational support (binary: yes or no)
# 19. paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# 20. activities - extra-curricular activities (binary: yes or no)
# 21. nursery - attended nursery school (binary: yes or no)
# 22. higher - wants to take higher education (binary: yes or no)
# 23. internet - Internet access at home (binary: yes or no)
# 24. romantic - with a romantic relationship (binary: yes or no)
# 25. famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# 26. freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# 27. goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# 28. Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 29. Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 30. health - current health status (numeric: from 1 - very bad to 5 - very good)
# 31. absences - number of school absences (numeric: from 0 to 93)
#
# These grades are related with the course subject, Math or Portuguese:
#
# 32. G1 - first period grade (numeric: from 0 to 20)
# 33. G2 - second period grade (numeric: from 0 to 20)
# 34. G3 - final grade (numeric: from 0 to 20, output target)
#
# Additional note: there are several (382) students that belong to both datasets .<br>
# These students can be identified by searching for identical attributes that characterize each student, as shown in the annexed R file.<br>
#
# __Source Information__
#
# P. Cortez and A. Silva. Using Data Mining to Predict Secondary School Student Performance. In A. Brito and J. Teixeira Eds., Proceedings of 5th FUture BUsiness TEChnology Conference (FUBUTEC 2008) pp. 5-12, Porto, Portugal, April, 2008, EUROSIS, ISBN 978-9077381-39-7.<br><br>
#
# Fabio Pagnotta, Hossain Mohammad Amran.
# Email:fabio.pagnotta@studenti.unicam.it, mohammadamra.hossain '@' studenti.unicam.it
# University Of Camerino<br><br>
#
# https://archive.ics.uci.edu/ml/datasets/STUDENT+ALCOHOL+CONSUMPTION
#
# Kaggle link : https://www.kaggle.com/uciml/student-alcohol-consumption/data

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import SelectKBest,  f_classif
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# ## Load Dataset

# %%
#load dataset
mat = pd.read_csv("dataset/student-mat.csv")
por = pd.read_csv("dataset/student-por.csv")

# %%
#dataset shape
print("Math dataset has ", mat.shape[0] ," row with ", mat.shape[1], "attributes")
print("Portugese dataset has ", por.shape[0] ," row with ", por.shape[1], "attributes")
# Out:
# Math dataset has  395  row with  33 attributes
# Portugese dataset has  649  row with  33 attributes

# %% [markdown]
# ## Data Cleaning

# %%
#copy dataset
dfmat = mat.copy()
dfpor = por.copy()

# %% [markdown]
# __Check Missing Values__

# %%
#math dataset
dfmat.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
#por dataset
dfpor.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# Both of dataset has no missing values.

# %% [markdown]
# __Check duplicated dataset__

# %%
#math dataset
dfmat.duplicated().sum()
# Out:
# 0

# %%
#portugese dataset
dfpor.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Also both of dataset has no duplicated values.

# %% [markdown]
# __Check Cardinality of Dataset__

# %%
#check unique values / cardinality
for x in dfmat.columns:
    print("Total unique values of", x , ":" ,len(dfmat[x].unique()))
    print(dfmat[x].unique())
    print("")

print("==================================")
print("")

#check unique values / cardinality
for x in dfpor.columns:
    print("Total unique values of", x , ":" ,len(dfpor[x].unique()))
    print(dfpor[x].unique())
    print("")
# Out:
# Total unique values of school : 2
# ['GP' 'MS']
#
# Total unique values of sex : 2
# ['F' 'M']
#
# Total unique values of age : 8
# [18 17 15 16 19 22 20 21]
#
# Total unique values of address : 2
# ['U' 'R']
#
# Total unique values of famsize : 2
# ['GT3' 'LE3']
#
# Total unique values of Pstatus : 2
# ['A' 'T']
#
# Total unique values of Medu : 5
# [4 1 3 2 0]
#
# Total unique values of Fedu : 5
# [4 1 2 3 0]
#
# Total unique values of Mjob : 5
# ['at_home' 'health' 'other' 'services' 'teacher']
#
# Total unique values of Fjob : 5
# ['teacher' 'other' 'services' 'health' 'at_home']
#
# Total unique values of reason : 4
# ['course' 'other' 'home' 'reputation']
#
# Total unique values of guardian : 3
# ['mother' 'father' 'other']
#
# Total unique values of traveltime : 4
# [2 1 3 4]
#
# Total unique values of studytime : 4
# [2 3 1 4]
#
# Total unique values of failures : 4
# [0 3 2 1]
#
# Total unique values of schoolsup : 2
# ['yes' 'no']
#
# Total unique values of famsup : 2
# ...

# %% [markdown]
# From both dataset we dont found any weird unique values , so we could continue.

# %% [markdown]
# ## Descriptive Analysis

# %% [markdown]
# __Composition of each final Grade__

# %%
fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.histplot(dfmat["G3"], discrete=True, bins=20, kde=True, ax=ax[0], color="tomato")
ax[0].set_title("Math Grade 3 Distribution")
sns.histplot(dfpor["G3"], discrete=True, bins=17, kde=True, ax=ax[1], color="royalblue")
ax[1].set_title("Portugese Grade 3 Distribution")

plt.show()

# %% [markdown]
# From above Final Grade (G3) distribution of Math and Portugese, we could see both of them has almost normal distribution. But we have a small tail in left (on grad 0).
#
# In this case, we will has assumption 0 final grade are not valid so we have final grade (G3) with normal distribution in both Math or Portugese. It might because 0 final grade are caused by student who not attend or has special condition so they got 0. This 0 grade could be elaborate in separated project.

# %%
#Drop 0 final grade
dfmat = dfmat.drop(dfmat[dfmat["G3"]==0].index)
dfpor = dfpor.drop(dfpor[dfpor["G3"]==0].index)

# %%
fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.histplot(dfmat["G3"], discrete=True, bins=20, kde=True, ax=ax[0], color="tomato")
ax[0].set_title("Math Grade 3 Distribution")
sns.histplot(dfpor["G3"], discrete=True, bins=17, kde=True, ax=ax[1], color="royalblue")
ax[1].set_title("Portugese Grade 3 Distribution")

plt.show()

# %% [markdown]
# And now we have more normal distributed graph in both Math and Portugese, so we could use statistic method which needs normal distribution assumption on it.

# %% [markdown]
# ## Attributes Association against Final Grade

# %% [markdown]
# __Categorical Attributes__

# %% [markdown]
# In this section, we'll find out which attributes has high association or relation with Final Grade of student Math and Portugese. We are using ANNOVA test approach to find the result.
#
# __Hyphotesis for each attributes:__ <br>
# H0 = All group at each attributes has same means of G3<br>
# H1 = All group at each attributes has differnt means of G3<br>
#
#
# Significance value = 0.05<br>
# Assumption : We have normal distributed of G3 grade

# %%
## ANOVA CALCULATION ##
mat_encoder = OrdinalEncoder()
por_encoder = OrdinalEncoder()

cat_mat = dfmat[['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health']]

cat_por = dfpor[['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health']]

cat_mats = mat_encoder.fit_transform(cat_mat)
cat_pors = por_encoder.fit_transform(cat_por)

#define feature selection generator
fs_mat = SelectKBest(score_func=f_classif ,k ="all")
fs_por = SelectKBest(score_func=f_classif ,k ="all")


#apply categorical feature and target 
X_mat_cat = fs_mat.fit_transform(cat_mats, dfmat["G3"])
X_por_cat = fs_por.fit_transform(cat_pors, dfpor["G3"])

# %%
mat_test = pd.DataFrame({"att":cat_mat.columns, "pvalue":fs_mat.pvalues_ , "annovascore":fs_mat.scores_})
por_test = pd.DataFrame({"att":cat_por.columns, "pvalue":fs_por.pvalues_ , "annovascore":fs_por.scores_})

#barplot
plt.figure(figsize=(15,5));
plt.bar(mat_test["att"],mat_test["pvalue"], color="tomato");
plt.axhline(y=0.05, color='g', linestyle='-')
plt.xlabel("P-Value")
plt.xticks(rotation=45)
plt.title("Math")
plt.show()

#barplot
plt.figure(figsize=(15,5));
plt.bar(por_test["att"],por_test["pvalue"], color="royalblue");
plt.axhline(y=0.05, color='r', linestyle='-')
plt.xticks(rotation=45)
plt.title("Portugese")
plt.xlabel("P-Value")
plt.show()

# %% [markdown]
# Result :
#
# From above graph we would focus on attributes which has P-value < 0.05, means those attributes are reject null hypothesis or in other hands all classess in those attritbutes doesnt have same mean and has impact to G3 Grade of students.
#
# From Math perspective, attributes which has impact to G3 are:
# - address
# - failures
# - schooshup
# - goout
# - Dalc
# - Walc
#
# While from perspective, attributes which has impact to G3 are:
# - school
# - age
# - address
# - Medu
# - Fedu
# - Mjob
# - reason
# - traveltime
# - studytime
# - failures
# - higher
# - Dalc
# - Walc
#
# So, to find out which attributes who has impact to both Math or Portugese final grade, we will only focus at attributes which has impact to both of them , such as :
# 1. address
# 2. failures
# 3. Dalc
# 4. Walc

# %% [markdown]
# __Numerical Attributes__

# %%
fig, ax = plt.subplots(4,2, figsize=(16,20))

ax[0,0].scatter(x=dfmat["age"], y =dfmat["G3"], color="tomato")
ax[0,0].set(ylabel="G3", xlabel="Age", title="MATH")
ax[1,0].scatter(x=dfmat["absences"], y =dfmat["G3"], color="tomato")
ax[1,0].set(ylabel="G3", xlabel="Absences")
ax[2,0].scatter(x=dfmat["G1"], y =dfmat["G3"], color="tomato")
ax[2,0].set(ylabel="G3", xlabel="G1")
ax[3,0].scatter(x=dfmat["G2"], y =dfmat["G3"], color="tomato")
ax[3,0].set(ylabel="G3", xlabel="G2")


ax[0,1].scatter(x=dfpor["age"], y =dfpor["G3"], color="royalblue")
ax[0,1].set(ylabel="G3", xlabel="Age",title="PORTUGESE")
ax[1,1].scatter(x=dfpor["absences"], y =dfpor["G3"], color="royalblue")
ax[1,1].set(ylabel="G3", xlabel="Absences")
ax[2,1].scatter(x=dfpor["G1"], y =dfpor["G3"], color="royalblue")
ax[2,1].set(ylabel="G3", xlabel="G1")
ax[3,1].scatter(x=dfpor["G2"], y =dfpor["G3"], color="royalblue")
ax[3,1].set(ylabel="G3", xlabel="G2")

plt.show()

# %% [markdown]
# From above scatter plot, we could see only G1 and G2 which has positive relationship against G3 (Final Grade) of student for both Math or Portugese. Typically if G1 and G2 increase, the final grade (G3) of student will follow to grow. While age and absences has no strong relationship because the scatter are tend to spread well.

# %% [markdown]
# ## Descriptive Analysis (In Deep)

# %% [markdown]
# __Address Attributes__

# %%
q1m = dfmat.groupby("address")["G3"].count().reset_index()
q1p = dfpor.groupby("address")["G3"].count().reset_index()

fig, ax = plt.subplots(1,2, figsize=(16,4))
ax[0].pie(q1m["G3"], autopct="%.2f%%", colors=["bisque","orangered"],textprops={'color':"black"}, labels=q1m["address"])
ax[0].set_title("Math address Proportion")
ax[0].legend()
ax[1].pie(q1p["G3"], autopct="%.2f%%", colors=["cornflowerblue","darkblue"],textprops={'color':"w"}, labels=q1p["address"])
ax[1].set_title("Portugese address Proportion")
ax[1].legend()
plt.show()


fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.histplot(data = dfmat, x="G3", discrete=True, bins=20, kde=True, ax=ax[0],hue="address", palette="Set2")
sns.histplot(data = dfpor, x="G3", discrete=True, bins=17, kde=True, ax=ax[1], color="royalblue",hue="address", palette="husl")
plt.show()


fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.boxplot(x="address", y="G3",  data=dfmat, ax=ax[0])
sns.boxplot(x="address", y="G3",  data=dfpor, ax=ax[1])
plt.show()

# %% [markdown]
# From above pie chart, we could see that most of student, abov 70% are live in Urban area while the rest are in Rural. It happened on both Math and Portugese.
#
# From distribution and boxplot chart, we could see both of math and portugese also has similar pattern of curve and mean distribution. Typically student who live in urban area has higher final grade than in rural. This might be happen because in urban, technology and environment are more modern than rural. It affecting the way of student learn and impact the final grade.

# %% [markdown]
# __Failures Attributes__

# %%
fig, ax = plt.subplots(1,2, figsize=(16,4))

sns.countplot(x="failures",  data =dfmat, palette=["bisque","orangered"], ax=ax[0])
ax[0].set_title("Math Failures Proportion")
sns.countplot(x="failures",  data =dfpor, palette=["cornflowerblue","darkblue"], ax=ax[1])
ax[1].set_title("Portugese Failures Proportion")
plt.show()

fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.histplot(data = dfmat, x="G3", discrete=True, bins=20, kde=True, ax=ax[0],hue="failures", palette="Set2")
sns.histplot(data = dfpor, x="G3", discrete=True, bins=17, kde=True, ax=ax[1], color="royalblue",hue="failures", palette="husl")
plt.show()

fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.boxplot(x="failures", y="G3",  data=dfmat, ax=ax[0])
sns.boxplot(x="failures", y="G3",  data=dfpor, ax=ax[1])
plt.show()

# %% [markdown]
# From bar plot we could see both of Math or Portugese, mostly has the students with 0 failures.
#
# From distribution graph , we could got some information :
# - In math, the curve of each failures represent that student with 0 failures tend to has higher final grade in 10 ,11 and 15. The more failures done, they tend to has lower final grade.
# - In portugese, the curve pattern almost same with math. Students with lower failures has higher final grade eventhough the difference between failure groups is not really significant.
#
# From boxplot graph, the mean of each failures classes are different. Lower failure has more higher means. We could say student with low failure tend to more focus in their study so they got more higher grade. While student with more failure , usually they have difficulty in study regarding their environment or even themself.

# %% [markdown]
# __Daily Alcohol Attributes__

# %%
fig, ax = plt.subplots(1,2, figsize=(16,4))

sns.countplot(x="Dalc",  data =dfmat, palette=["bisque","orangered"], ax=ax[0])
ax[0].set_title("Math Daily Alcohol Proportion")
sns.countplot(x="Dalc",  data =dfpor, palette=["cornflowerblue","darkblue"], ax=ax[1])
ax[1].set_title("Portugese Daily Alcohol Proportion")
plt.show()

fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.histplot(data = dfmat, x="G3", discrete=True, bins=20, kde=True, ax=ax[0],hue="Dalc", palette="Set2")
sns.histplot(data = dfpor, x="G3", discrete=True, bins=17, kde=True, ax=ax[1], color="royalblue",hue="Dalc", palette="husl")
plt.show()

fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.boxplot(x="Dalc", y="G3",  data=dfmat, ax=ax[0])
sns.boxplot(x="Dalc", y="G3",  data=dfpor, ax=ax[1])
plt.show()

# %% [markdown]
# From above bar graph we could see, the proportion of daily alcohol frequency of students are same in Math or Portugese. Mostly students consume alcohol in weekday are very low.
#
# But from disribution graph, we could see both of Math and Portugese also has similar pattern of curve. The lowest frequency of alcohol they drinks, the higher final grade they have. It could be seen in peak of every curves in the graph.
#
# Eventhough from the boxplot their means of each frequency almost similar, but the boundary of each Dalc classess tells us the more often student drink in weekday, the lower final grade they will have.

# %% [markdown]
# __Weekend Alcohol Attributes__

# %%
fig, ax = plt.subplots(1,2, figsize=(16,4))

sns.countplot(x="Walc",  data =dfmat, palette=["bisque","orangered"], ax=ax[0])
ax[0].set_title("Math Weekend Alcohol Proportion")
sns.countplot(x="Walc",  data =dfpor, palette=["cornflowerblue","darkblue"], ax=ax[1])
ax[1].set_title("Portugese Weekend Alcohol Proportion")
plt.show()

fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.histplot(data = dfmat, x="G3", discrete=True, bins=20, kde=True, ax=ax[0],hue="Walc", palette="Set2")
sns.histplot(data = dfpor, x="G3", discrete=True, bins=17, kde=True, ax=ax[1], color="royalblue",hue="Walc", palette="husl")
plt.show()

fig, ax = plt.subplots(1,2, figsize=(16,4))
sns.boxplot(x="Walc", y="G3",  data=dfmat, ax=ax[0])
sns.boxplot(x="Walc", y="G3",  data=dfpor, ax=ax[1])
plt.show()

# %% [markdown]
# Same with daily alcohol, in weekend alcohol attributes, both Math and Portugese has similar propotion. Mostly students has very low frequency in drinking alchol , but the number of frequency 2 - 5 are increased than weekend alcohol. This migth be happened because at weekend student tend to hangout with friends and drink together.
#
# From distribution graph, we could see both Math and Portugese also has similar pattern of curves. Student who has frequency of weekend alcohol from 1-2 (low) has similar final grade, while the often they drink they tend to has lower final grade.

# %% [markdown]
# ## Conclusion
#
# From above explanation, we could say below are attributes who has strong impact to student final grade (G3):
# - G1 and G2 grade of student give positive impact to Final Grade (G3)
# - Student who live in urban give more positive impact to final grade.
# - Number failures of student, Weekly Alcohol Frequency, Weekend alcohol frequency give negative impact to findal grade of student.
#
#
# For next input :
# - The research might continue in creating a regression model to predict the final grade that student got based on their behaviour regarding their G1,G2, address, failures, alcohol consumption.
# - Another research might be conduct in future regarding student who got 0 in their final grade and find out what's might happening.
